# %%
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib.colors as colors

# %%
time_y_THot = xr.load_dataarray('~/projects/thermal/output/sky_TmaxAreaTmean_ts.nc')

# %%
time_y_THot
# Out:
# <xarray.DataArray 'meanTcoldsky' (time: 3001, Y: 103)>
# array([[ 11.322727 ,   9.591818 ,   6.399091 , ..., -15.597273 ,
#         -15.924545 , -16.571817 ],
#        [ 11.4972725,   9.81     ,   6.5118184, ..., -15.47     ,
#         -15.986363 , -16.57909  ],
#        [ 11.617272 ,   9.948182 ,   6.5918183, ..., -15.466364 ,
#         -16.011818 , -16.571817 ],
#        ...,
#        [ 11.548182 ,   8.057273 ,   5.271818 , ..., -31.597273 ,
#         -31.786364 , -31.960909 ],
#        [ 11.551818 ,   7.9990907,   5.2536364, ..., -31.466364 ,
#         -31.73909  , -31.902727 ],
#        [ 11.3154545,   7.7372727,   4.871818 , ..., -31.960909 ,
#         -32.197273 , -32.157272 ]], dtype=float32)
# Coordinates:
#   * Y        (Y) int32 150 151 152 153 154 155 156 ... 247 248 249 250 251 252
#   * time     (time) datetime64[ns] 2022-04-15T12:49:45 ... 2022-04-15T16:27:46
# Attributes:
#     units:    celsius

# %%
fig, ax = plt.subplots(nrows=2, figsize=(15, 6))
time_y_THot.plot.contourf(ax=ax[0], x='time', cmap='plasma', levels =50, vmin=-40, vmax=120)
time_y_TCold.plot.contourf(ax=ax[1], x='time', cmap='plasma', levels =50, vmin=-40, vmax=120)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/n3/f96m4s896csf9kg60t5bb4sw0000gq/T/ipykernel_47153/3538137987.py in <module>
#       1 fig, ax = plt.subplots(nrows=2, figsize=(15, 6))
#       2 time_y_THot.plot.contourf(ax=ax[0], x='time', cmap='plasma', levels =50, vmin=-40, vmax=120)
# ----> 3 time_y_TCold.plot.contourf(ax=ax[1], x='time', cmap='plasma', levels =50, vmin=-40, vmax=120)
#
# NameError: name 'time_y_TCold' is not defined

# %%
fig, ax = plt.subplots(figsize=(20, 4))
levs = [-20, -15, -10, -5]+ [i for i in range(100)]
fmt = '%1.0f'
time_y_THot.sel(time=slice('2022-04-15 13', '2022-04-15 17')).plot.contourf(x='time', cmap='plasma', levels=120, vmin=-20, vmax=110, norm=colors.SymLogNorm(11), 
                         cbar_kwargs={'format': fmt, 'label': 'Temperature [$^\circ$C]', 
                                     'aspect':20, 'shrink': 1})

#cbar_kwargs={'location': "left", 'format': fmt, 'label': 'Temperature [$^\circ$C]',
                                     #'fraction': 0.01, 'aspect':50, 'shrink': 0.7}

plt.savefig('/Users/bhupendra/projects/thermal/plots/thermal_tY-Tmean_smoke.pdf')

# %%
fig, ax = plt.subplots(figsize=(16, 5))
levs = [-20, -15, -10, -5]+ [i for i in range(100)]
fmt = '%1.0f'
time_y_TCold.plot.contourf(x='time', cmap='plasma', levels=120, vmin=-20, vmax=110, norm=colors.SymLogNorm(10), 
                         cbar_kwargs={'location': "bottom", 'format': fmt, 'label': 'Temperature [$^\circ$C]', 
                                     'aspect':50})


plt.savefig('/Users/bhupendra/projects/thermal/plots/thermal_tY-Tmean_cold_sky.pdf')
